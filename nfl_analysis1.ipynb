# %%
# !pip install pymysql
# Out:
# ...
#     100% |████████████████████████████████| 77kB 647kB/s
# ...
# You are using pip version 8.0.2, however version 8.1.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pymysql

# %%
# Connect to the database
connection = pymysql.connect(host='104.196.5.55',
                             user='root',
                             db='nfl',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)

# %%
import pandas as pd
pd.read_sql('select * from pass', connection, index_col=None, coerce_float=True, params=None, parse_dates=None, columns=None)
# Out:
#            pid      psr      trg loc  yds  comp  succ  spk      dfb
# 0            3  JG-0600  JR-2000  NL   10     1     1    0       \r
# 1            5  JG-0600  TO-0200  NL   19     1     1    0       \r
# 2            7  JG-0600  CG-0400  NL   24     1     1    0       \r
# 3            9  JG-0600  FB-0200  NL    4     1     1    0       \r
# 4           15  CC-1400  BC-1100  NL    0     0     0    0       \r
# 5           16  CC-1400  TM-0900  NL    0     0     0    0       \r
# 6           20  JG-0600  JR-2000  NL    0     0     0    0       \r
# 7           21  JG-0600  GC-0500  NL    8     1     0    0       \r
# 8           24  CC-1400  SJ-0400  NL    0     0     0    0       \r
# 9           25  CC-1400  TM-0900  NL   17     1     1    0       \r
# 10          26  CC-1400  SJ-0400  NL    0     0     0    0       \r
# 11          28  CC-1400  CC-1400  NL   -4     1     0    0       \r
# 12          29  CC-1400  JA-1600  NL   20     1     1    0       \r
# ...
